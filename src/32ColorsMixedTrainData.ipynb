# %% [markdown]
# <a href="https://colab.research.google.com/github/yepinshuo/Image_Colorization/blob/main/32ColorsMixedTrainData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dropout, MaxPooling2D, Conv2D, Dense
from keras.datasets import cifar10
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from skimage.color import rgb2grey
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
X = np.vstack((X_train,X_test))
y = np.vstack((y_train,y_test))

# %%
y = y.flatten()

# %%
X.shape, y.shape
# Out:
# ((60000, 32, 32, 3), (60000,))

# %%
for i in range(0,16):
    axis = plt.subplot(4,4,i+1)
    arr = X[i]
    axis.imshow(arr)
    plt.axis('off')
plt.show()

# %%
X.shape, y.shape
# Out:
# ((60000, 32, 32, 3), (60000,))

# %%
X = X[:10000]
y = y[:10000]

# %%
X.size
# Out:
# 30720000

# %%
X = X.reshape((10000*32*32,3))
X.shape
# Out:
# (10240000, 3)

# %%
kmeans = KMeans(n_clusters=32,random_state=0)
kmeans = kmeans.fit(X)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 90.99221472, 113.80686872,  49.40439309],
#        [161.16147949, 168.63153147, 174.72131398],
#        [128.35695537, 129.00340886, 124.60989576],
#        [ 64.17680986,  54.61078317,  34.13084328],
#        [210.66492702, 209.51086605, 207.32922928],
#        [204.49784739, 178.40040958, 106.05900103],
#        [112.91004212, 108.87742972,  95.78907318],
#        [249.65789992, 250.43069545, 249.81493498],
#        [ 71.36623383,  71.43130244,  63.48211899],
#        [194.54265173, 128.59363438,  70.0800119 ],
#        [125.99453251, 169.43875433, 215.39999083],
#        [185.42199023, 169.93209848, 148.27587044],
#        [130.12566485, 151.35895883,  76.56569463],
#        [102.40723831,  85.33798812,  66.03857925],
#        [115.79006315, 141.16198737, 167.34041589],
#        [ 12.23699861,  11.3613691 ,  10.84310768],
#        [ 60.52881349, 123.23481929, 182.7838391 ],
#        [107.0764837 ,  55.29439775,  33.3199337 ],
#        [227.69901752, 230.1574289 , 229.58273162],
#        [146.39959934, 122.21440431,  96.02047308],
#        [187.7736934 , 187.9312607 , 187.06534808],
#        [ 34.62220114,  32.25334431,  27.99863972],
#        [150.31627434, 149.95841976, 146.19150178],
#        [137.94789184, 100.14820824,  60.98617085],
#        [ 45.0338867 ,  51.57721836,  55.44290799],
#        [ 43.46756972,  75.6726223 , 114.73015323],
#        [173.36874761, 202.56181557, 229.30929687],
#        [ 84.84560203,  90.05382412,  89.9549401 ],
#        [165.30230547, 148.99019079, 115.65305752],
#        [ 91.19498571, 110.83382897, 127.66073702],
#        [221.58914614, 201.60557105, 164.94883304],
#        [186.12339272,  48.81717318,  41.09855781]])

# %%
X_new = X

# %%
X.shape
# Out:
# (10240000, 3)

# %%
for i in range(len(X)):
    X_new[i] = kmeans.cluster_centers_[kmeans.labels_[i]]

# %%
X_viz = X_new.reshape((10000,32,32,3))
for i in range(0,16):
    axis = plt.subplot(4,4,i+1)
    arr = X_viz[i]
    axis.imshow(arr)
    plt.axis('off')
plt.show()

# %%
from keras import utils as np_utils
y_N = keras.utils.np_utils.to_categorical(kmeans.labels_).reshape((10000,32,32,32))

# %%
X = X.reshape((10000,32,32,3))
X_N = []
for i in range(len(X)):
    X_N.append(rgb2grey(X[i]).tolist())
X_N = np.array(X_N)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: rgb2grey is deprecated. It will be removed in version 0.19.Please use rgb2gray instead.
#   after removing the cwd from sys.path.

# %%
for i in range(0,16):
    axis = plt.subplot(4,4,i+1)
    arr = X_N[i]
    axis.imshow(arr,cmap='gray')
    plt.axis('off')
plt.show()

# %%
X_N.shape
# Out:
# (10000, 32, 32)

# %%
X_N = X_N.reshape((10000,32,32,1))
X_N.shape, y_N.shape
# Out:
# ((10000, 32, 32, 1), (10000, 32, 32, 32))

# %%
X_train = X_N[0:9984]
y_train = y_N[0:9984]
X_test = X_N[-16:]
y_test = y_N[-16:]
X_train = np.vstack((X_train,X_test))
y_train = np.vstack((y_train,y_test))
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((10000, 32, 32, 1), (10000, 32, 32, 32), (16, 32, 32, 1), (16, 32, 32, 32))

# %%
cnn = Sequential()
cnn.add(Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(32,32,1)))
cnn.add(Conv2D(128, (3,3), activation='relu', padding='same'))
cnn.add(Conv2D(128, (3,3), activation='relu', padding='same'))
cnn.add(Conv2D(128, (3,3), activation='relu', padding='same'))
cnn.add(Conv2D(64, (3,3), activation='relu', padding='same'))
cnn.add(Dense(64, activation='relu'))
cnn.add(Dense(32, activation='relu'))
cnn.add(Dense(32, activation='softmax'))
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        73792
#
#  dense (Dense)               (None, 32, 32, 64)        4160
#
#  dense_1 (Dense)             (None, 32, 32, 32)        2080
#
#  dense_2 (Dense)             (None, 32, 32, 32)        1056
#
# =================================================================
# Total params: 450,752
# Trainable params: 450,752
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn.compile(loss='mean_squared_error', optimizer='adam', metrics = ['accuracy'])
history = cnn.fit(X_train, y_train, epochs=100, validation_split=0.1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Train vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 282/282 [==============================] - 29s 68ms/step - loss: 0.0270 - accuracy: 0.2169 - val_loss: 0.0223 - val_accuracy: 0.4285
# Epoch 2/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0184 - accuracy: 0.5463 - val_loss: 0.0224 - val_accuracy: 0.4525
# Epoch 3/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0158 - accuracy: 0.6261 - val_loss: 0.0159 - val_accuracy: 0.6103
# Epoch 4/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0135 - accuracy: 0.6823 - val_loss: 0.0167 - val_accuracy: 0.6196
# Epoch 5/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0130 - accuracy: 0.7019 - val_loss: 0.0123 - val_accuracy: 0.6699
# Epoch 6/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0116 - accuracy: 0.7279 - val_loss: 0.0188 - val_accuracy: 0.5971
# Epoch 7/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0117 - accuracy: 0.7367 - val_loss: 0.0112 - val_accuracy: 0.6947
# Epoch 8/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0107 - accuracy: 0.7571 - val_loss: 0.0107 - val_accuracy: 0.7351
# Epoch 9/100
# 282/282 [==============================] - 18s 64ms/step - loss: 0.0100 - accuracy: 0.7706 - val_loss: 0.0107 - val_accuracy: 0.7479
# Epoch 10/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0102 - accuracy: 0.7648 - val_loss: 0.0084 - val_accuracy: 0.8148
# Epoch 11/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0117 - accuracy: 0.7462 - val_loss: 0.0116 - val_accuracy: 0.7586
# Epoch 12/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0107 - accuracy: 0.7689 - val_loss: 0.0131 - val_accuracy: 0.7229
# Epoch 13/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0129 - accuracy: 0.7301 - val_loss: 0.0165 - val_accuracy: 0.6538
# Epoch 14/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0147 - accuracy: 0.6949 - val_loss: 0.0182 - val_accuracy: 0.5964
# Epoch 15/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0129 - accuracy: 0.7229 - val_loss: 0.0166 - val_accuracy: 0.6618
# Epoch 16/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0149 - accuracy: 0.6821 - val_loss: 0.0118 - val_accuracy: 0.7205
# Epoch 17/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0126 - accuracy: 0.7185 - val_loss: 0.0114 - val_accuracy: 0.7584
# Epoch 18/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0117 - accuracy: 0.7393 - val_loss: 0.0157 - val_accuracy: 0.6492
# Epoch 19/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0126 - accuracy: 0.7203 - val_loss: 0.0269 - val_accuracy: 0.4684
# Epoch 20/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0134 - accuracy: 0.7013 - val_loss: 0.0143 - val_accuracy: 0.6411
# Epoch 21/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0114 - accuracy: 0.7441 - val_loss: 0.0128 - val_accuracy: 0.7133
# Epoch 22/100
# 282/282 [==============================] - 18s 66ms/step - loss: 0.0130 - accuracy: 0.7101 - val_loss: 0.0103 - val_accuracy: 0.7774
# Epoch 23/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0113 - accuracy: 0.7446 - val_loss: 0.0100 - val_accuracy: 0.7666
# Epoch 24/100
# 282/282 [==============================] - 18s 66ms/step - loss: 0.0119 - accuracy: 0.7352 - val_loss: 0.0130 - val_accuracy: 0.7099
# Epoch 25/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0135 - accuracy: 0.7078 - val_loss: 0.0094 - val_accuracy: 0.7909
# Epoch 26/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0120 - accuracy: 0.7296 - val_loss: 0.0118 - val_accuracy: 0.7238
# Epoch 27/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0121 - accuracy: 0.7268 - val_loss: 0.0102 - val_accuracy: 0.7749
# Epoch 28/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0120 - accuracy: 0.7317 - val_loss: 0.0105 - val_accuracy: 0.7590
# Epoch 29/100
# 282/282 [==============================] - 20s 72ms/step - loss: 0.0123 - accuracy: 0.7264 - val_loss: 0.0111 - val_accuracy: 0.7461
# Epoch 30/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0114 - accuracy: 0.7487 - val_loss: 0.0094 - val_accuracy: 0.7906
# Epoch 31/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0106 - accuracy: 0.7597 - val_loss: 0.0076 - val_accuracy: 0.8330
# Epoch 32/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0089 - accuracy: 0.7967 - val_loss: 0.0077 - val_accuracy: 0.8280
# Epoch 33/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0120 - accuracy: 0.7357 - val_loss: 0.0139 - val_accuracy: 0.6858
# Epoch 34/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0098 - accuracy: 0.7758 - val_loss: 0.0076 - val_accuracy: 0.8284
# Epoch 35/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0098 - accuracy: 0.7782 - val_loss: 0.0078 - val_accuracy: 0.8250
# Epoch 36/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0102 - accuracy: 0.7698 - val_loss: 0.0087 - val_accuracy: 0.8021
# Epoch 37/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0090 - accuracy: 0.7956 - val_loss: 0.0111 - val_accuracy: 0.7668
# Epoch 38/100
# 282/282 [==============================] - 18s 66ms/step - loss: 0.0109 - accuracy: 0.7569 - val_loss: 0.0126 - val_accuracy: 0.7115
# Epoch 39/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0099 - accuracy: 0.7758 - val_loss: 0.0114 - val_accuracy: 0.7444
# Epoch 40/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0090 - accuracy: 0.7953 - val_loss: 0.0077 - val_accuracy: 0.8264
# Epoch 41/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0096 - accuracy: 0.7827 - val_loss: 0.0080 - val_accuracy: 0.8155
# Epoch 42/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0106 - accuracy: 0.7670 - val_loss: 0.0134 - val_accuracy: 0.7091
# Epoch 43/100
# 282/282 [==============================] - 18s 66ms/step - loss: 0.0116 - accuracy: 0.7445 - val_loss: 0.0080 - val_accuracy: 0.8149
# Epoch 44/100
# 282/282 [==============================] - 18s 66ms/step - loss: 0.0110 - accuracy: 0.7605 - val_loss: 0.0126 - val_accuracy: 0.7079
# Epoch 45/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0104 - accuracy: 0.7683 - val_loss: 0.0094 - val_accuracy: 0.7949
# Epoch 46/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0092 - accuracy: 0.7911 - val_loss: 0.0092 - val_accuracy: 0.7934
# Epoch 47/100
# 282/282 [==============================] - 18s 66ms/step - loss: 0.0096 - accuracy: 0.7820 - val_loss: 0.0085 - val_accuracy: 0.8201
# Epoch 48/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0107 - accuracy: 0.7672 - val_loss: 0.0117 - val_accuracy: 0.7521
# Epoch 49/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0108 - accuracy: 0.7646 - val_loss: 0.0100 - val_accuracy: 0.7779
# Epoch 50/100
# 282/282 [==============================] - 18s 65ms/step - loss: 0.0086 - accuracy: 0.8046 - val_loss: 0.0206 - val_accuracy: 0.5826
# Epoch 51/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0112 - accuracy: 0.7544 - val_loss: 0.0085 - val_accuracy: 0.8099
# Epoch 52/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0085 - accuracy: 0.8070 - val_loss: 0.0094 - val_accuracy: 0.7848
# Epoch 53/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0095 - accuracy: 0.7869 - val_loss: 0.0229 - val_accuracy: 0.5297
# Epoch 54/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0170 - accuracy: 0.6564 - val_loss: 0.0156 - val_accuracy: 0.6930
# Epoch 55/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0165 - accuracy: 0.6680 - val_loss: 0.0146 - val_accuracy: 0.7039
# Epoch 56/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0138 - accuracy: 0.7097 - val_loss: 0.0101 - val_accuracy: 0.7869
# Epoch 57/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0123 - accuracy: 0.7400 - val_loss: 0.0112 - val_accuracy: 0.7591
# Epoch 58/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0121 - accuracy: 0.7450 - val_loss: 0.0100 - val_accuracy: 0.7889
# Epoch 59/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0114 - accuracy: 0.7534 - val_loss: 0.0109 - val_accuracy: 0.7614
# Epoch 60/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0092 - accuracy: 0.7955 - val_loss: 0.0064 - val_accuracy: 0.8503
# Epoch 61/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0068 - accuracy: 0.8479 - val_loss: 0.0104 - val_accuracy: 0.7770
# Epoch 62/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0069 - accuracy: 0.8452 - val_loss: 0.0081 - val_accuracy: 0.8140
# Epoch 63/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0062 - accuracy: 0.8623 - val_loss: 0.0131 - val_accuracy: 0.7198
# Epoch 64/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0055 - accuracy: 0.8784 - val_loss: 0.0044 - val_accuracy: 0.9007
# Epoch 65/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0049 - accuracy: 0.8909 - val_loss: 0.0047 - val_accuracy: 0.8967
# Epoch 66/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0058 - accuracy: 0.8729 - val_loss: 0.0057 - val_accuracy: 0.8733
# Epoch 67/100
# 282/282 [==============================] - 19s 68ms/step - loss: 0.0078 - accuracy: 0.8376 - val_loss: 0.0051 - val_accuracy: 0.8899
# Epoch 68/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0059 - accuracy: 0.8741 - val_loss: 0.0075 - val_accuracy: 0.8468
# Epoch 69/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0062 - accuracy: 0.8663 - val_loss: 0.0056 - val_accuracy: 0.8715
# Epoch 70/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0051 - accuracy: 0.8875 - val_loss: 0.0058 - val_accuracy: 0.8681
# Epoch 71/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0067 - accuracy: 0.8550 - val_loss: 0.0072 - val_accuracy: 0.8372
# Epoch 72/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0068 - accuracy: 0.8487 - val_loss: 0.0071 - val_accuracy: 0.8444
# Epoch 73/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0090 - accuracy: 0.8053 - val_loss: 0.0160 - val_accuracy: 0.6839
# Epoch 74/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0083 - accuracy: 0.8184 - val_loss: 0.0078 - val_accuracy: 0.8247
# Epoch 75/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0091 - accuracy: 0.8008 - val_loss: 0.0082 - val_accuracy: 0.8064
# Epoch 76/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0084 - accuracy: 0.8110 - val_loss: 0.0111 - val_accuracy: 0.7729
# Epoch 77/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0078 - accuracy: 0.8234 - val_loss: 0.0077 - val_accuracy: 0.8168
# Epoch 78/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0079 - accuracy: 0.8186 - val_loss: 0.0163 - val_accuracy: 0.6732
# Epoch 79/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0077 - accuracy: 0.8262 - val_loss: 0.0110 - val_accuracy: 0.7766
# Epoch 80/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0075 - accuracy: 0.8351 - val_loss: 0.0092 - val_accuracy: 0.7964
# Epoch 81/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0088 - accuracy: 0.8088 - val_loss: 0.0064 - val_accuracy: 0.8578
# Epoch 82/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0069 - accuracy: 0.8466 - val_loss: 0.0113 - val_accuracy: 0.7517
# Epoch 83/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0071 - accuracy: 0.8424 - val_loss: 0.0072 - val_accuracy: 0.8371
# Epoch 84/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0085 - accuracy: 0.8128 - val_loss: 0.0063 - val_accuracy: 0.8554
# Epoch 85/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0064 - accuracy: 0.8496 - val_loss: 0.0058 - val_accuracy: 0.8630
# Epoch 86/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0070 - accuracy: 0.8397 - val_loss: 0.0065 - val_accuracy: 0.8501
# Epoch 87/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0060 - accuracy: 0.8584 - val_loss: 0.0058 - val_accuracy: 0.8598
# Epoch 88/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0074 - accuracy: 0.8317 - val_loss: 0.0055 - val_accuracy: 0.8674
# Epoch 89/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0075 - accuracy: 0.8308 - val_loss: 0.0081 - val_accuracy: 0.8218
# Epoch 90/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0084 - accuracy: 0.8153 - val_loss: 0.0201 - val_accuracy: 0.5961
# Epoch 91/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0117 - accuracy: 0.7349 - val_loss: 0.0109 - val_accuracy: 0.7407
# Epoch 92/100
# 282/282 [==============================] - 19s 67ms/step - loss: 0.0098 - accuracy: 0.7703 - val_loss: 0.0094 - val_accuracy: 0.7727
# Epoch 93/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0105 - accuracy: 0.7529 - val_loss: 0.0103 - val_accuracy: 0.7545
# Epoch 94/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0104 - accuracy: 0.7509 - val_loss: 0.0133 - val_accuracy: 0.6787
# Epoch 95/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0104 - accuracy: 0.7517 - val_loss: 0.0110 - val_accuracy: 0.7352
# Epoch 96/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0097 - accuracy: 0.7637 - val_loss: 0.0106 - val_accuracy: 0.7415
# Epoch 97/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0099 - accuracy: 0.7614 - val_loss: 0.0095 - val_accuracy: 0.7667
# Epoch 98/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0098 - accuracy: 0.7599 - val_loss: 0.0112 - val_accuracy: 0.7268
# Epoch 99/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0093 - accuracy: 0.7696 - val_loss: 0.0090 - val_accuracy: 0.7742
# Epoch 100/100
# 282/282 [==============================] - 19s 66ms/step - loss: 0.0096 - accuracy: 0.7655 - val_loss: 0.0107 - val_accuracy: 0.7433

# %%
predictions = cnn.predict(X_test)
predictions.shape
# Out:
# (16, 32, 32, 32)

# %%
predictions = predictions.reshape((16384,32))
pred = predictions[:,0:3]
for i in range(len(predictions)):
    pred[i] = kmeans.cluster_centers_[np.argmax(predictions[i])].tolist()
pred = pred.reshape((16,32,32,3))

# %%
y_test.shape
# Out:
# (16, 32, 32, 32)

# %%
real = y_test.reshape((16384,32))
yy = real[:, 0:3]
for i in range(len(real)):
  yy[i] = kmeans.cluster_centers_[np.argmax(real[i])].tolist()
yy = yy.reshape((16,32,32,3))

# %%
for i in range(0,16):
    axis = plt.subplot(4,4,i+1)
    arr = X_test.reshape(16,32,32)[i]
    axis.imshow(arr, cmap='gray')
    plt.axis('off')
plt.show()

# %%
for i in range(0,16):
    axis = plt.subplot(4,4,i+1)
    arr = yy[i]
    axis.imshow(arr.astype(np.uint8))
    plt.axis('off')
plt.show()

# %%
for i in range(0,16):
    axis = plt.subplot(4,4,i+1)
    arr = pred[i]
    axis.imshow(arr.astype(np.uint8))
    plt.axis('off')
plt.show()
